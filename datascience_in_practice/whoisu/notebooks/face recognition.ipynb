# %%
import face_recognition as fr
from IPython.display import Image
from PIL import Image as PILImage
import glob
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for fn in glob.glob('img/shit_shit/brad_turned_left.jpg'):
    image = fr.load_image_file(fn)
    image = np.rot90(image,3)
    face_locations = fr.face_locations(image)
    top, right, bottom, left = face_locations[0]
    face_image = image[top:bottom, left:right]
    
    small_img = PILImage.fromarray(face_image)
    display(small_img.resize((64,64)))
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F32F8632E80>

# %%
for fn in glob.glob('../img/Eren_Elci/*.jpg'):
    image = fr.load_image_file(fn)
    image = np.rot90(image,3)
    face_locations = fr.face_locations(image)
    top, right, bottom, left = face_locations[0]
    face_image = image[top:bottom, left:right]
    
    small_img = PILImage.fromarray(face_image)
    display(small_img.resize((64,64)))
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F2F4C55A2B0>
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F2F4C5350F0>
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F2F4C55A2B0>
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F2F4C535320>
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F2F4C55A2B0>
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F2F4C535320>
